# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import random

# Use the citipy module to determine city based on latitude
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_current = city_weather["weather"][0]["main"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Currently": city_current,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | sungaipenuh
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | gambela
# Processing Record 7 of Set 1 | morrope
# Processing Record 8 of Set 1 | wladyslawowo
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | inhambane
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | neka
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | yarmouth
# Processing Record 16 of Set 1 | kitgum
# Processing Record 17 of Set 1 | igarka
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | grand gaube
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | prainha
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | sorada
# Processing Record 31 of Set 1 | kapit
# Processing Record 32 of Set 1 | jardim
# Processing Record 33 of Set 1 | kara-tyube
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | calolziocorte
# Processing Record 36 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 1 | queenstown
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | bulungu
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | morondava
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | nome
# Processing Record 47 of Set 1 | sola
# Processing Record 48 of Set 1 | ahipara
# Processing Record 49 of Set 1 | kuusamo
# Processing Record 50 of Set 1 | walvis bay
# Processing Record 1 of Set 2 | caravelas
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 2 | gat
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | klaksvik
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | sobolevo
# Processing Record 14 of Set 2 | tiznit
# Processing Record 15 of Set 2 | deputatskiy
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | nemuro
# Processing Record 18 of Set 2 | tutoia
# Processing Record 19 of Set 2 | port blair
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | kilindoni
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | camacha
# Processing Record 24 of Set 2 | kochubey
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | kibuye
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | kearney
# Processing Record 29 of Set 2 | komsomolskiy
# Processing Record 30 of Set 2 | cabedelo
# Processing Record 31 of Set 2 | elizabeth city
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | chikwawa
# Processing Record 34 of Set 2 | necochea
# Processing Record 35 of Set 2 | kpandu
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | acari
# Processing Record 38 of Set 2 | laela
# Processing Record 39 of Set 2 | berezna
# Processing Record 40 of Set 2 | tucurui
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | gizycko
# Processing Record 47 of Set 2 | foshan
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | richmond
# Processing Record 50 of Set 2 | saint-augustin
# Processing Record 1 of Set 3 | alyangula
# Processing Record 2 of Set 3 | nouadhibou
# Processing Record 3 of Set 3 | aklavik
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | balsta
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | piryion
# City not found. Skipping...
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | turiacu
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | jawhar
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | vila franca do campo
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | heihe
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | sergeyevka
# Processing Record 22 of Set 3 | plettenberg bay
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | sinjar
# Processing Record 28 of Set 3 | kargil
# Processing Record 29 of Set 3 | kieta
# Processing Record 30 of Set 3 | saint marys
# Processing Record 31 of Set 3 | waipawa
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | saint-joseph
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 3 | luderitz
# Processing Record 37 of Set 3 | neryungri
# Processing Record 38 of Set 3 | visnes
# Processing Record 39 of Set 3 | ostrovnoy
# Processing Record 40 of Set 3 | evans
# Processing Record 41 of Set 3 | sawakin
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | chapais
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | port moresby
# Processing Record 47 of Set 3 | susanville
# Processing Record 48 of Set 3 | lesozavodsk
# Processing Record 49 of Set 3 | safaga
# Processing Record 50 of Set 3 | merauke
# Processing Record 1 of Set 4 | pangody
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | ambon
# Processing Record 4 of Set 4 | beira
# Processing Record 5 of Set 4 | tarakan
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | honningsvag
# Processing Record 11 of Set 4 | tecpan
# Processing Record 12 of Set 4 | acapulco
# Processing Record 13 of Set 4 | champerico
# Processing Record 14 of Set 4 | villa rica
# Processing Record 15 of Set 4 | pangoa
# Processing Record 16 of Set 4 | point pedro
# Processing Record 17 of Set 4 | yambio
# Processing Record 18 of Set 4 | mehamn
# Processing Record 19 of Set 4 | denpasar
# Processing Record 20 of Set 4 | vagur
# Processing Record 21 of Set 4 | lokosovo
# Processing Record 22 of Set 4 | presidencia roque saenz pena
# Processing Record 23 of Set 4 | pontes e lacerda
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | cartagena del chaira
# Processing Record 26 of Set 4 | kodinsk
# Processing Record 27 of Set 4 | jamsa
# Processing Record 28 of Set 4 | altay
# Processing Record 29 of Set 4 | chernyanka
# Processing Record 30 of Set 4 | turkan
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | barrow
# Processing Record 35 of Set 4 | wanaka
# Processing Record 36 of Set 4 | ekhabi
# Processing Record 37 of Set 4 | mundi
# Processing Record 38 of Set 4 | ayan
# Processing Record 39 of Set 4 | okha
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | porto santo
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | araguacu
# Processing Record 44 of Set 4 | ust-tsilma
# Processing Record 45 of Set 4 | prestea
# Processing Record 46 of Set 4 | vuktyl
# Processing Record 47 of Set 4 | tasiilaq
# Processing Record 48 of Set 4 | brae
# Processing Record 49 of Set 4 | hofn
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | bay roberts
# Processing Record 2 of Set 5 | surami
# Processing Record 3 of Set 5 | eskisehir
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 5 | kysyl-syr
# Processing Record 9 of Set 5 | manado
# Processing Record 10 of Set 5 | tres picos
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | tuktoyaktuk
# Processing Record 13 of Set 5 | svetlaya
# Processing Record 14 of Set 5 | kamenka
# Processing Record 15 of Set 5 | abu dhabi
# Processing Record 16 of Set 5 | hillsborough
# Processing Record 17 of Set 5 | ugoofaaru
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | kavieng
# Processing Record 20 of Set 5 | chalons-en-champagne
# Processing Record 21 of Set 5 | prabumulih
# Processing Record 22 of Set 5 | shemonaikha
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | tawang
# Processing Record 26 of Set 5 | dunedin
# Processing Record 27 of Set 5 | kasongo-lunda
# Processing Record 28 of Set 5 | joao pessoa
# Processing Record 29 of Set 5 | kununurra
# Processing Record 30 of Set 5 | alekseyevskaya
# Processing Record 31 of Set 5 | madang
# Processing Record 32 of Set 5 | monrovia
# Processing Record 33 of Set 5 | contamana
# Processing Record 34 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | havoysund
# Processing Record 38 of Set 5 | luxor
# Processing Record 39 of Set 5 | axim
# Processing Record 40 of Set 5 | olinda
# Processing Record 41 of Set 5 | mithi
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | thaton
# Processing Record 44 of Set 5 | beruwala
# Processing Record 45 of Set 5 | matagami
# Processing Record 46 of Set 5 | gloversville
# Processing Record 47 of Set 5 | namatanai
# Processing Record 48 of Set 5 | panama city
# Processing Record 49 of Set 5 | tabou
# Processing Record 50 of Set 5 | dudinka
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | gao
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | athabasca
# Processing Record 5 of Set 6 | dedza
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | fuerte olimpo
# Processing Record 9 of Set 6 | comodoro rivadavia
# Processing Record 10 of Set 6 | manggar
# Processing Record 11 of Set 6 | manta
# Processing Record 12 of Set 6 | hithadhoo
# Processing Record 13 of Set 6 | newberry
# Processing Record 14 of Set 6 | college
# Processing Record 15 of Set 6 | aksum
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | kruisfontein
# Processing Record 18 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 6 | bathsheba
# Processing Record 20 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 6 | birsk
# Processing Record 22 of Set 6 | makat
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | zambezi
# Processing Record 25 of Set 6 | ranong
# Processing Record 26 of Set 6 | srivardhan
# Processing Record 27 of Set 6 | tadine
# Processing Record 28 of Set 6 | asyut
# Processing Record 29 of Set 6 | aksaray
# Processing Record 30 of Set 6 | port hedland
# Processing Record 31 of Set 6 | husavik
# Processing Record 32 of Set 6 | corinth
# Processing Record 33 of Set 6 | fort nelson
# Processing Record 34 of Set 6 | coihaique
# Processing Record 35 of Set 6 | vero beach
# Processing Record 36 of Set 6 | poli
# Processing Record 37 of Set 6 | umm kaddadah
# Processing Record 38 of Set 6 | baykit
# Processing Record 39 of Set 6 | santiago del estero
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | herstal
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | ghanzi
# Processing Record 44 of Set 6 | pemba
# Processing Record 45 of Set 6 | ljungby
# Processing Record 46 of Set 6 | kano
# Processing Record 47 of Set 6 | marpingen
# Processing Record 48 of Set 6 | adrar
# Processing Record 49 of Set 6 | kamaishi
# Processing Record 50 of Set 6 | praia da vitoria
# Processing Record 1 of Set 7 | toora-khem
# Processing Record 2 of Set 7 | carnarvon
# Processing Record 3 of Set 7 | jocon
# Processing Record 4 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 7 | kuytun
# Processing Record 6 of Set 7 | ternate
# Processing Record 7 of Set 7 | darhan
# Processing Record 8 of Set 7 | kozhva
# Processing Record 9 of Set 7 | opuwo
# Processing Record 10 of Set 7 | aksu
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | townsville
# Processing Record 14 of Set 7 | shumskiy
# Processing Record 15 of Set 7 | khash
# Processing Record 16 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | perwez
# Processing Record 19 of Set 7 | thinadhoo
# Processing Record 20 of Set 7 | falam
# Processing Record 21 of Set 7 | gazojak
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | ixtapa
# Processing Record 24 of Set 7 | hambantota
# Processing Record 25 of Set 7 | meulaboh
# Processing Record 26 of Set 7 | bjornevatn
# Processing Record 27 of Set 7 | orlik
# Processing Record 28 of Set 7 | biltine
# Processing Record 29 of Set 7 | sheltozero
# Processing Record 30 of Set 7 | marzuq
# Processing Record 31 of Set 7 | innisfail
# Processing Record 32 of Set 7 | ocos
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | bure
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | shelburne
# Processing Record 37 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 38 of Set 7 | hammerfest
# Processing Record 39 of Set 7 | camana
# Processing Record 40 of Set 7 | bardiyah
# Processing Record 41 of Set 7 | tahlequah
# Processing Record 42 of Set 7 | psebay
# Processing Record 43 of Set 7 | port hawkesbury
# Processing Record 44 of Set 7 | amiens
# Processing Record 45 of Set 7 | gerede
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | malangali
# Processing Record 48 of Set 7 | assenede
# Processing Record 49 of Set 7 | pangai
# Processing Record 50 of Set 7 | poya
# Processing Record 1 of Set 8 | maceio
# Processing Record 2 of Set 8 | minna
# Processing Record 3 of Set 8 | tumsar
# Processing Record 4 of Set 8 | gogrial
# Processing Record 5 of Set 8 | hirara
# Processing Record 6 of Set 8 | teupasenti
# Processing Record 7 of Set 8 | sinegorye
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | nikolskoye
# Processing Record 10 of Set 8 | grand baie
# Processing Record 11 of Set 8 | kiama
# Processing Record 12 of Set 8 | atasu
# Processing Record 13 of Set 8 | victoria
# Processing Record 14 of Set 8 | iquique
# Processing Record 15 of Set 8 | badarganj
# Processing Record 16 of Set 8 | mwinilunga
# Processing Record 17 of Set 8 | temiscaming
# Processing Record 18 of Set 8 | the valley
# Processing Record 19 of Set 8 | batticaloa
# Processing Record 20 of Set 8 | eureka
# Processing Record 21 of Set 8 | castro
# Processing Record 22 of Set 8 | villa de reyes
# Processing Record 23 of Set 8 | udimskiy
# Processing Record 24 of Set 8 | georgiyevka
# Processing Record 25 of Set 8 | longhua
# Processing Record 26 of Set 8 | tilichiki
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | valdivia
# Processing Record 29 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 8 | selma
# Processing Record 31 of Set 8 | asau
# Processing Record 32 of Set 8 | shache
# Processing Record 33 of Set 8 | anito
# Processing Record 34 of Set 8 | dauphin
# Processing Record 35 of Set 8 | pandamatenga
# Processing Record 36 of Set 8 | erzin
# Processing Record 37 of Set 8 | gobo
# Processing Record 38 of Set 8 | bamnet narong
# Processing Record 39 of Set 8 | tower
# Processing Record 40 of Set 8 | northam
# Processing Record 41 of Set 8 | dingle
# Processing Record 42 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 8 | pizarro
# Processing Record 44 of Set 8 | quchan
# Processing Record 45 of Set 8 | kulhudhuffushi
# Processing Record 46 of Set 8 | villazon
# Processing Record 47 of Set 8 | curup
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | diego de almagro
# Processing Record 50 of Set 8 | oktyabrskoye
# Processing Record 1 of Set 9 | beringovskiy
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | pedernales
# Processing Record 4 of Set 9 | katsuura
# Processing Record 5 of Set 9 | pak phanang
# Processing Record 6 of Set 9 | antofagasta
# Processing Record 7 of Set 9 | geraldton
# Processing Record 8 of Set 9 | lazaro cardenas
# Processing Record 9 of Set 9 | mayo
# Processing Record 10 of Set 9 | leningradskiy
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | jalu
# Processing Record 13 of Set 9 | esso
# Processing Record 14 of Set 9 | tshikapa
# Processing Record 15 of Set 9 | jumla
# Processing Record 16 of Set 9 | yerbogachen
# Processing Record 17 of Set 9 | isangel
# Processing Record 18 of Set 9 | ornskoldsvik
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | dostpur
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | ijuin
# Processing Record 23 of Set 9 | abay
# Processing Record 24 of Set 9 | sistranda
# Processing Record 25 of Set 9 | asfi
# Processing Record 26 of Set 9 | stonewall
# Processing Record 27 of Set 9 | mao
# Processing Record 28 of Set 9 | la sarre
# Processing Record 29 of Set 9 | davila
# Processing Record 30 of Set 9 | kaitangata
# Processing Record 31 of Set 9 | diamantino
# Processing Record 32 of Set 9 | kashirskoye
# Processing Record 33 of Set 9 | xiamen
# Processing Record 34 of Set 9 | zyryanka
# Processing Record 35 of Set 9 | bud
# Processing Record 36 of Set 9 | lagoa
# Processing Record 37 of Set 9 | bambui
# Processing Record 38 of Set 9 | salamanca
# Processing Record 39 of Set 9 | krutinka
# Processing Record 40 of Set 9 | usinsk
# Processing Record 41 of Set 9 | jertih
# Processing Record 42 of Set 9 | kristiansund
# Processing Record 43 of Set 9 | tomatlan
# Processing Record 44 of Set 9 | mayumba
# Processing Record 45 of Set 9 | maracacume
# Processing Record 46 of Set 9 | biak
# Processing Record 47 of Set 9 | senneterre
# Processing Record 48 of Set 9 | naze
# Processing Record 49 of Set 9 | vanavara
# Processing Record 50 of Set 9 | tole
# Processing Record 1 of Set 10 | san quintin
# Processing Record 2 of Set 10 | yeniseysk
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | lakheri
# Processing Record 5 of Set 10 | mar del plata
# Processing Record 6 of Set 10 | matara
# Processing Record 7 of Set 10 | raudeberg
# Processing Record 8 of Set 10 | sao joao da barra
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | wiang sa
# Processing Record 11 of Set 10 | karasjok
# Processing Record 12 of Set 10 | humaita
# Processing Record 13 of Set 10 | hailun
# Processing Record 14 of Set 10 | kokopo
# Processing Record 15 of Set 10 | pisco
# Processing Record 16 of Set 10 | kajaani
# Processing Record 17 of Set 10 | piacabucu
# Processing Record 18 of Set 10 | avera
# Processing Record 19 of Set 10 | havelock
# Processing Record 20 of Set 10 | ust-kuyga
# Processing Record 21 of Set 10 | flin flon
# Processing Record 22 of Set 10 | saint-pierre
# Processing Record 23 of Set 10 | souillac
# Processing Record 24 of Set 10 | birjand
# Processing Record 25 of Set 10 | shiliguri
# Processing Record 26 of Set 10 | agdas
# Processing Record 27 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 10 | urubicha
# Processing Record 29 of Set 10 | straumen
# Processing Record 30 of Set 10 | hearst
# Processing Record 31 of Set 10 | haines junction
# Processing Record 32 of Set 10 | jining
# Processing Record 33 of Set 10 | lobito
# Processing Record 34 of Set 10 | dakoro
# Processing Record 35 of Set 10 | svay rieng
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | salinopolis
# Processing Record 38 of Set 10 | olafsvik
# Processing Record 39 of Set 10 | bam
# Processing Record 40 of Set 10 | kamphaeng phet
# Processing Record 41 of Set 10 | tambun
# Processing Record 42 of Set 10 | araouane
# Processing Record 43 of Set 10 | bukama
# Processing Record 44 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 10 | santo andre
# Processing Record 46 of Set 10 | mogok
# Processing Record 47 of Set 10 | north las vegas
# Processing Record 48 of Set 10 | collie
# Processing Record 49 of Set 10 | marondera
# Processing Record 50 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 11 | kathu
# Processing Record 2 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | longyearbyen
# Processing Record 4 of Set 11 | halifax
# Processing Record 5 of Set 11 | santa rosa
# Processing Record 6 of Set 11 | nema
# Processing Record 7 of Set 11 | esna
# Processing Record 8 of Set 11 | yeppoon
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | saint-francois
# Processing Record 11 of Set 11 | baijiantan
# Processing Record 12 of Set 11 | kashi
# Processing Record 13 of Set 11 | salalah
# Processing Record 14 of Set 11 | saucillo
# Processing Record 15 of Set 11 | bonthe
# Processing Record 16 of Set 11 | salym
# Processing Record 17 of Set 11 | kargasok
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | rosario
# Processing Record 20 of Set 11 | henties bay
# Processing Record 21 of Set 11 | kemnay
# Processing Record 22 of Set 11 | volkach
# Processing Record 23 of Set 11 | strezhevoy
# Processing Record 24 of Set 11 | vilhena
# Processing Record 25 of Set 11 | umm lajj
# Processing Record 26 of Set 11 | birao
# Processing Record 27 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 11 | finschhafen
# Processing Record 29 of Set 11 | yar-sale
# Processing Record 30 of Set 11 | ottawa
# Processing Record 31 of Set 11 | ojinaga
# Processing Record 32 of Set 11 | magesti
# Processing Record 33 of Set 11 | llanes
# Processing Record 34 of Set 11 | gamba
# Processing Record 35 of Set 11 | bilma
# Processing Record 36 of Set 11 | warrnambool
# Processing Record 37 of Set 11 | ponta delgada
# Processing Record 38 of Set 11 | valreas
# Processing Record 39 of Set 11 | kupang
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | cockburn town
# Processing Record 42 of Set 11 | gerstetten
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | san cristobal
# Processing Record 45 of Set 11 | houma
# Processing Record 46 of Set 11 | kommunar
# Processing Record 47 of Set 11 | north bend
# Processing Record 48 of Set 11 | yurimaguas
# Processing Record 49 of Set 11 | tura
# Processing Record 50 of Set 11 | porto nacional
# Processing Record 1 of Set 12 | harper
# Processing Record 2 of Set 12 | nishihara
# Processing Record 3 of Set 12 | tevaitoa
# Processing Record 4 of Set 12 | godda
# Processing Record 5 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 12 | naron
# Processing Record 7 of Set 12 | evensk
# Processing Record 8 of Set 12 | requena
# Processing Record 9 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 12 | port macquarie
# Processing Record 12 of Set 12 | hrubieszow
# Processing Record 13 of Set 12 | noumea
# Processing Record 14 of Set 12 | buraydah
# Processing Record 15 of Set 12 | buritizeiro
# Processing Record 16 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 12 | arroyos y esteros
# Processing Record 18 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 12 | anadyr
# Processing Record 20 of Set 12 | sitka
# Processing Record 21 of Set 12 | biu
# Processing Record 22 of Set 12 | belyy yar
# Processing Record 23 of Set 12 | yulara
# Processing Record 24 of Set 12 | salinas
# Processing Record 25 of Set 12 | naantali
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | tommot
# Processing Record 28 of Set 12 | chumikan
# Processing Record 29 of Set 12 | tahta
# Processing Record 30 of Set 12 | qinhuangdao
# Processing Record 31 of Set 12 | rawson
# Processing Record 32 of Set 12 | christchurch
# Processing Record 33 of Set 12 | egvekinot
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | linxia
# Processing Record 36 of Set 12 | lerwick
# Processing Record 37 of Set 12 | martinsburg
# Processing Record 38 of Set 12 | dembi dolo
# Processing Record 39 of Set 12 | pekan
# Processing Record 40 of Set 12 | santa fe
# Processing Record 41 of Set 12 | mackay
# Processing Record 42 of Set 12 | acarau
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | gourcy
# Processing Record 45 of Set 12 | staraya toropa
# Processing Record 46 of Set 12 | bermeo
# Processing Record 47 of Set 12 | tessalit
# Processing Record 48 of Set 12 | shingu
# Processing Record 49 of Set 12 | coahuayana
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | zhengjiatun
# Processing Record 2 of Set 13 | porto seguro
# Processing Record 3 of Set 13 | lanzhou
# Processing Record 4 of Set 13 | ambulu
# Processing Record 5 of Set 13 | greeneville
# Processing Record 6 of Set 13 | lata
# Processing Record 7 of Set 13 | nyurba
# Processing Record 8 of Set 13 | san jeronimo
# Processing Record 9 of Set 13 | ayer itam
# City not found. Skipping...
# Processing Record 10 of Set 13 | banda aceh
# Processing Record 11 of Set 13 | bani walid
# Processing Record 12 of Set 13 | zhangjiakou
# Processing Record 13 of Set 13 | akureyri
# Processing Record 14 of Set 13 | nagato
# Processing Record 15 of Set 13 | mogadouro
# Processing Record 16 of Set 13 | pringsewu
# Processing Record 17 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 13 | neiafu
# Processing Record 19 of Set 13 | batemans bay
# Processing Record 20 of Set 13 | amapa
# Processing Record 21 of Set 13 | itarema
# Processing Record 22 of Set 13 | dezful
# Processing Record 23 of Set 13 | palmer
# Processing Record 24 of Set 13 | los llanos de aridane
# Processing Record 25 of Set 13 | carupano
# Processing Record 26 of Set 13 | svetlogorsk
# Processing Record 27 of Set 13 | korla
# Processing Record 28 of Set 13 | zeya
# Processing Record 29 of Set 13 | sayansk
# Processing Record 30 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 13 | novorzhev
# Processing Record 32 of Set 13 | pokhara
# Processing Record 33 of Set 13 | diffa
# Processing Record 34 of Set 13 | moree
# Processing Record 35 of Set 13 | tambo
# Processing Record 36 of Set 13 | turkistan
# Processing Record 37 of Set 13 | sorland
# Processing Record 38 of Set 13 | okhotsk
# Processing Record 39 of Set 13 | romny
# Processing Record 40 of Set 13 | rossland
# Processing Record 41 of Set 13 | shenjiamen
# Processing Record 42 of Set 13 | iralaya
# Processing Record 43 of Set 13 | baglan
# Processing Record 44 of Set 13 | nantucket
# Processing Record 45 of Set 13 | dukat
# Processing Record 46 of Set 13 | srednekolymsk
# Processing Record 47 of Set 13 | tazovskiy
# Processing Record 48 of Set 13 | ha tinh
# Processing Record 49 of Set 13 | kendari
# Processing Record 50 of Set 13 | oranjestad
# Processing Record 1 of Set 14 | zhigansk
# Processing Record 2 of Set 14 | lysa hora
# Processing Record 3 of Set 14 | jinxi
# Processing Record 4 of Set 14 | high level
# Processing Record 5 of Set 14 | tottori
# Processing Record 6 of Set 14 | dakar
# Processing Record 7 of Set 14 | tiarei
# Processing Record 8 of Set 14 | gornoye loo
# Processing Record 9 of Set 14 | phulji
# Processing Record 10 of Set 14 | vallenar
# Processing Record 11 of Set 14 | conceicao do araguaia
# Processing Record 12 of Set 14 | lithakia
# Processing Record 13 of Set 14 | nsoko
# Processing Record 14 of Set 14 | palasa
# Processing Record 15 of Set 14 | isla vista
# Processing Record 16 of Set 14 | kastamonu
# Processing Record 17 of Set 14 | vryheid
# Processing Record 18 of Set 14 | richards bay
# Processing Record 19 of Set 14 | puerto del rosario
# Processing Record 20 of Set 14 | ruteng
# Processing Record 21 of Set 14 | fairbanks
# Processing Record 22 of Set 14 | cabra
# Processing Record 23 of Set 14 | hovd
# Processing Record 24 of Set 14 | sartell
# Processing Record 25 of Set 14 | moerai
# Processing Record 26 of Set 14 | nadym
# Processing Record 27 of Set 14 | byumba
# Processing Record 28 of Set 14 | ilhabela
# Processing Record 29 of Set 14 | lasa
# Processing Record 30 of Set 14 | grindavik
# Processing Record 31 of Set 14 | flinders
# Processing Record 32 of Set 14 | pouebo
# Processing Record 33 of Set 14 | minab
# Processing Record 34 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 14 | agadez
# Processing Record 36 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 14 | bulgan
# Processing Record 38 of Set 14 | vila do maio
# Processing Record 39 of Set 14 | dongsheng
# Processing Record 40 of Set 14 | duartina
# Processing Record 41 of Set 14 | alofi
# Processing Record 42 of Set 14 | pathein
# Processing Record 43 of Set 14 | ewa beach
# Processing Record 44 of Set 14 | palu
# Processing Record 45 of Set 14 | maragogi
# Processing Record 46 of Set 14 | glendive
# Processing Record 47 of Set 14 | paithan
# Processing Record 48 of Set 14 | udachnyy
# Processing Record 49 of Set 14 | tsogni
# Processing Record 50 of Set 14 | nizhniy odes
# Processing Record 1 of Set 15 | sur
# Processing Record 2 of Set 15 | ouargaye
# Processing Record 3 of Set 15 | santa cruz
# Processing Record 4 of Set 15 | mahajanga
# Processing Record 5 of Set 15 | ciudad bolivar
# Processing Record 6 of Set 15 | hamilton
# Processing Record 7 of Set 15 | auki
# Processing Record 8 of Set 15 | christiana
# Processing Record 9 of Set 15 | omboue
# Processing Record 10 of Set 15 | kampot
# Processing Record 11 of Set 15 | nakhodka
# Processing Record 12 of Set 15 | tagusao
# Processing Record 13 of Set 15 | surbo
# Processing Record 14 of Set 15 | oktyabrskiy
# Processing Record 15 of Set 15 | tautira
# Processing Record 16 of Set 15 | formosa
# Processing Record 17 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | staryy nadym
# Processing Record 19 of Set 15 | kabo
# Processing Record 20 of Set 15 | olga
# Processing Record 21 of Set 15 | rio rancho
# Processing Record 22 of Set 15 | maniitsoq
# Processing Record 23 of Set 15 | casper
# Processing Record 24 of Set 15 | lorengau
# Processing Record 25 of Set 15 | urengoy
# Processing Record 26 of Set 15 | kongoussi
# Processing Record 27 of Set 15 | andenes
# Processing Record 28 of Set 15 | lavrentiya
# Processing Record 29 of Set 15 | araceli
# Processing Record 30 of Set 15 | san rafael
# Processing Record 31 of Set 15 | verkhnyaya sinyachikha
# Processing Record 32 of Set 15 | dolores
# Processing Record 33 of Set 15 | varkkallai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Currently  Max Temp  Humidity  Cloudiness  \
# 0         Tiksi  71.6872  128.8694    Clouds     38.03        79         100
# 1   Sungaipenuh  -2.0833  101.3833    Clouds     63.99        97          50
# 2       Rikitea -23.1203 -134.9692      Rain     72.61        78          98
# 3       Mataura -46.1927  168.8643    Clouds     44.47        99          96
# 4       Gambela   8.2500   34.5833      Rain     69.66        98         100
# 5       Morrope  -6.5417  -80.0111    Clouds     77.11        58          58
# 6  Wladyslawowo  54.7909   18.4009     Clear     71.15        85           2
# 7        Kodiak  57.7900 -152.4072     Clear     65.71        63           1
# 8     Inhambane -23.8650   35.3833      Rain     63.28        84          17
# 9         Kapaa  22.0752 -159.3190      Rain     82.38        80          90
#
#    Wind Speed Country                 Date
# 0        9.89      RU  2021-07-17 19:10:29
# 1        1.83      ID  2021-07-17 19:10:29
# 2       26.89      PF  2021-07-17 19:10:29
# 3        2.19      NZ  2021-07-17 19:10:29
# 4        3.98      ET  2021-07-17 19:10:30
# 5       14.92      PE  2021-07-17 19:10:30
# 6        8.08      PL  2021-07-17 19:10:30
# 7        3.44      US  2021-07-17 19:10:30
# 8        8.66      MZ  2021-07-17 19:10:31
# 9        1.99      US  2021-07-17 19:08:21

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
