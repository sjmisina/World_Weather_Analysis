# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import random

# Use the citipy module to determine city based on latitude
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_current = city_weather["weather"][0]["main"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Currently": city_current,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | noumea
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | barra do garcas
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | manono
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | xai-xai
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | mbanza-ngungu
# Processing Record 10 of Set 1 | muborak
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | moyale
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | dingle
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | mehamn
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | mathbaria
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | asosa
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | mugur-aksy
# Processing Record 26 of Set 1 | catamarca
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | boa viagem
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | laibin
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | avera
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | samdari
# Processing Record 38 of Set 1 | kismayo
# Processing Record 39 of Set 1 | maun
# Processing Record 40 of Set 1 | fort nelson
# Processing Record 41 of Set 1 | warrnambool
# Processing Record 42 of Set 1 | huarmey
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | mabaruma
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | inhambane
# Processing Record 2 of Set 2 | homer
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | lumeje
# Processing Record 6 of Set 2 | monrovia
# Processing Record 7 of Set 2 | honiara
# Processing Record 8 of Set 2 | ocos
# Processing Record 9 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 2 | pahrump
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | paita
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | haines junction
# Processing Record 16 of Set 2 | turayf
# Processing Record 17 of Set 2 | kavaratti
# Processing Record 18 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 2 | altayskoye
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | kuito
# Processing Record 22 of Set 2 | havelock
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | beringovskiy
# Processing Record 25 of Set 2 | narasannapeta
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | taltal
# Processing Record 28 of Set 2 | lokosovo
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | sambava
# Processing Record 31 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 2 | marsa matruh
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | buchanan
# Processing Record 35 of Set 2 | bucerias
# Processing Record 36 of Set 2 | marsh harbour
# Processing Record 37 of Set 2 | tucuman
# Processing Record 38 of Set 2 | mapastepec
# Processing Record 39 of Set 2 | vao
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | maicao
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | jamsa
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | rocha
# Processing Record 48 of Set 2 | goderich
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | hauterive
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | acari
# Processing Record 3 of Set 3 | benha
# City not found. Skipping...
# Processing Record 4 of Set 3 | paka
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | karaton
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | nombre de dios
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | hare bay
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | ambulu
# Processing Record 14 of Set 3 | kloulklubed
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | wattegama
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | pestovo
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | cherskiy
# Processing Record 26 of Set 3 | raisinghnagar
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | bayji
# Processing Record 30 of Set 3 | vardo
# Processing Record 31 of Set 3 | san cristobal
# Processing Record 32 of Set 3 | general pico
# Processing Record 33 of Set 3 | poum
# Processing Record 34 of Set 3 | tezu
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | chifeng
# Processing Record 38 of Set 3 | manicore
# Processing Record 39 of Set 3 | areia branca
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | mount isa
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 3 | toropets
# Processing Record 48 of Set 3 | sao jose da coroa grande
# Processing Record 49 of Set 3 | hovd
# Processing Record 50 of Set 3 | rio bananal
# Processing Record 1 of Set 4 | cajabamba
# Processing Record 2 of Set 4 | shelburne
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | tyukhtet
# Processing Record 6 of Set 4 | butaritari
# Processing Record 7 of Set 4 | dicabisagan
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | kudahuvadhoo
# Processing Record 10 of Set 4 | trairi
# Processing Record 11 of Set 4 | kasempa
# Processing Record 12 of Set 4 | iquitos
# Processing Record 13 of Set 4 | corrales
# Processing Record 14 of Set 4 | gat
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | nampula
# Processing Record 18 of Set 4 | chuy
# Processing Record 19 of Set 4 | kenai
# Processing Record 20 of Set 4 | ojinaga
# Processing Record 21 of Set 4 | flinders
# Processing Record 22 of Set 4 | broken hill
# Processing Record 23 of Set 4 | baculin
# Processing Record 24 of Set 4 | bosaso
# Processing Record 25 of Set 4 | uyutne
# Processing Record 26 of Set 4 | panama city
# Processing Record 27 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | smirnykh
# Processing Record 30 of Set 4 | port-gentil
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | padilla
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | port shepstone
# Processing Record 36 of Set 4 | mason city
# Processing Record 37 of Set 4 | antofagasta
# Processing Record 38 of Set 4 | puerto ayora
# Processing Record 39 of Set 4 | mayumba
# Processing Record 40 of Set 4 | santa isabel
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | pilao arcado
# City not found. Skipping...
# Processing Record 43 of Set 4 | evensk
# Processing Record 44 of Set 4 | naryan-mar
# Processing Record 45 of Set 4 | iralaya
# Processing Record 46 of Set 4 | half moon bay
# Processing Record 47 of Set 4 | ust-kuyga
# Processing Record 48 of Set 4 | lac du bonnet
# Processing Record 49 of Set 4 | tacotalpa
# Processing Record 50 of Set 4 | kawhia
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | opobo
# City not found. Skipping...
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | tessalit
# Processing Record 5 of Set 5 | lugovoy
# Processing Record 6 of Set 5 | neuquen
# Processing Record 7 of Set 5 | san jose de sisa
# Processing Record 8 of Set 5 | bochnia
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | constantine
# Processing Record 11 of Set 5 | lucapa
# Processing Record 12 of Set 5 | sindor
# Processing Record 13 of Set 5 | russell
# Processing Record 14 of Set 5 | tocopilla
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | kuva
# City not found. Skipping...
# Processing Record 17 of Set 5 | yarmouth
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | banfora
# Processing Record 20 of Set 5 | camacha
# Processing Record 21 of Set 5 | ganzhou
# Processing Record 22 of Set 5 | nome
# Processing Record 23 of Set 5 | rundu
# Processing Record 24 of Set 5 | sagua la grande
# Processing Record 25 of Set 5 | sanming
# Processing Record 26 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 5 | gorontalo
# Processing Record 28 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | claudio
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | oranjestad
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | lakes entrance
# Processing Record 36 of Set 5 | okhotsk
# Processing Record 37 of Set 5 | gushikawa
# Processing Record 38 of Set 5 | pontecagnano
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | saint-louis
# Processing Record 41 of Set 5 | santa fe
# Processing Record 42 of Set 5 | fukue
# Processing Record 43 of Set 5 | charters towers
# Processing Record 44 of Set 5 | chapais
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | luganville
# Processing Record 47 of Set 5 | avarua
# Processing Record 48 of Set 5 | saurimo
# Processing Record 49 of Set 5 | banjarmasin
# Processing Record 50 of Set 5 | vila
# Processing Record 1 of Set 6 | west bay
# Processing Record 2 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 3 of Set 6 | bulgan
# Processing Record 4 of Set 6 | nikolskoye
# Processing Record 5 of Set 6 | murgab
# Processing Record 6 of Set 6 | gao
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | williams lake
# Processing Record 12 of Set 6 | maceio
# Processing Record 13 of Set 6 | ternuvate
# Processing Record 14 of Set 6 | samarai
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 6 | kununurra
# Processing Record 18 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | mirnyy
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | seminole
# Processing Record 25 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 26 of Set 6 | faanui
# Processing Record 27 of Set 6 | richards bay
# Processing Record 28 of Set 6 | arkhangelsk
# Processing Record 29 of Set 6 | saint anthony
# Processing Record 30 of Set 6 | kapuskasing
# Processing Record 31 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 6 | igarka
# Processing Record 33 of Set 6 | hvide sande
# Processing Record 34 of Set 6 | betsiamites
# Processing Record 35 of Set 6 | batemans bay
# Processing Record 36 of Set 6 | washington
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | mingshui
# Processing Record 40 of Set 6 | vallauris
# Processing Record 41 of Set 6 | zemio
# Processing Record 42 of Set 6 | muli
# Processing Record 43 of Set 6 | georgetown
# Processing Record 44 of Set 6 | morant bay
# Processing Record 45 of Set 6 | southbridge
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 6 | maldonado
# Processing Record 49 of Set 6 | laguna
# Processing Record 50 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 7 | tongchuan
# Processing Record 2 of Set 7 | tautira
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | miri
# Processing Record 5 of Set 7 | kelso
# Processing Record 6 of Set 7 | saint-philippe
# Processing Record 7 of Set 7 | erenhot
# Processing Record 8 of Set 7 | marzuq
# Processing Record 9 of Set 7 | fort collins
# Processing Record 10 of Set 7 | santa vitoria do palmar
# Processing Record 11 of Set 7 | astoria
# Processing Record 12 of Set 7 | westport
# Processing Record 13 of Set 7 | zwedru
# Processing Record 14 of Set 7 | alto araguaia
# Processing Record 15 of Set 7 | kalmar
# Processing Record 16 of Set 7 | barbacoas
# Processing Record 17 of Set 7 | northam
# Processing Record 18 of Set 7 | pargolovo
# Processing Record 19 of Set 7 | satipo
# Processing Record 20 of Set 7 | komsomolskiy
# Processing Record 21 of Set 7 | camana
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | mount pleasant
# Processing Record 24 of Set 7 | kaeo
# Processing Record 25 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 7 | zaraza
# Processing Record 27 of Set 7 | puerto leguizamo
# Processing Record 28 of Set 7 | chardara
# Processing Record 29 of Set 7 | araxa
# Processing Record 30 of Set 7 | bubaque
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | san isidro
# Processing Record 33 of Set 7 | kutum
# Processing Record 34 of Set 7 | tura
# Processing Record 35 of Set 7 | portland
# Processing Record 36 of Set 7 | shawnee
# Processing Record 37 of Set 7 | wanning
# Processing Record 38 of Set 7 | roald
# Processing Record 39 of Set 7 | labuhan
# Processing Record 40 of Set 7 | sola
# Processing Record 41 of Set 7 | deer lake
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | ouallam
# Processing Record 45 of Set 7 | paamiut
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | ngunguru
# Processing Record 48 of Set 7 | cabatuan
# Processing Record 49 of Set 7 | eyl
# Processing Record 50 of Set 7 | longyearbyen
# Processing Record 1 of Set 8 | atasu
# Processing Record 2 of Set 8 | lata
# Processing Record 3 of Set 8 | rosarito
# Processing Record 4 of Set 8 | prince rupert
# Processing Record 5 of Set 8 | quzhou
# Processing Record 6 of Set 8 | burgos
# Processing Record 7 of Set 8 | cosala
# Processing Record 8 of Set 8 | sokoni
# Processing Record 9 of Set 8 | nhulunbuy
# Processing Record 10 of Set 8 | sri aman
# Processing Record 11 of Set 8 | kargil
# Processing Record 12 of Set 8 | paragould
# Processing Record 13 of Set 8 | waipawa
# Processing Record 14 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | kindu
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | bani walid
# Processing Record 18 of Set 8 | dudinka
# Processing Record 19 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | gizo
# Processing Record 22 of Set 8 | saquarema
# Processing Record 23 of Set 8 | mokrous
# Processing Record 24 of Set 8 | snasa
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | lensk
# Processing Record 27 of Set 8 | vanavara
# Processing Record 28 of Set 8 | pechenga
# Processing Record 29 of Set 8 | kilis
# Processing Record 30 of Set 8 | ambilobe
# Processing Record 31 of Set 8 | tilichiki
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | bethel
# Processing Record 34 of Set 8 | voznesenye
# Processing Record 35 of Set 8 | kannangad
# Processing Record 36 of Set 8 | dali
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 8 | codrington
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | gamba
# Processing Record 42 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 8 | koratla
# Processing Record 44 of Set 8 | rapid valley
# Processing Record 45 of Set 8 | kilingi-nomme
# Processing Record 46 of Set 8 | lagoa
# Processing Record 47 of Set 8 | corrente
# Processing Record 48 of Set 8 | port keats
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | sodertalje
# City not found. Skipping...
# Processing Record 1 of Set 9 | inongo
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | bengkulu
# Processing Record 4 of Set 9 | asyut
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | alyangula
# Processing Record 8 of Set 9 | keti bandar
# Processing Record 9 of Set 9 | severo-kurilsk
# Processing Record 10 of Set 9 | victoria point
# Processing Record 11 of Set 9 | jiaocheng
# Processing Record 12 of Set 9 | cayenne
# Processing Record 13 of Set 9 | torbay
# Processing Record 14 of Set 9 | kintinku
# Processing Record 15 of Set 9 | dorado
# Processing Record 16 of Set 9 | piacabucu
# Processing Record 17 of Set 9 | baruun-urt
# Processing Record 18 of Set 9 | bara
# Processing Record 19 of Set 9 | rabo de peixe
# Processing Record 20 of Set 9 | ginir
# Processing Record 21 of Set 9 | broome
# Processing Record 22 of Set 9 | san carlos
# Processing Record 23 of Set 9 | edd
# Processing Record 24 of Set 9 | ejutla de crespo
# Processing Record 25 of Set 9 | acapulco
# Processing Record 26 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 9 | castro-urdiales
# Processing Record 28 of Set 9 | sisimiut
# Processing Record 29 of Set 9 | robertsport
# Processing Record 30 of Set 9 | katherine
# Processing Record 31 of Set 9 | petrivka
# Processing Record 32 of Set 9 | togur
# Processing Record 33 of Set 9 | amahai
# Processing Record 34 of Set 9 | kibuye
# Processing Record 35 of Set 9 | munirabad
# Processing Record 36 of Set 9 | fairbanks
# Processing Record 37 of Set 9 | price
# Processing Record 38 of Set 9 | pevek
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | otukpo
# Processing Record 41 of Set 9 | huntingdon
# Processing Record 42 of Set 9 | camacupa
# Processing Record 43 of Set 9 | baturaja
# Processing Record 44 of Set 9 | mackay
# Processing Record 45 of Set 9 | puta
# Processing Record 46 of Set 9 | sebring
# Processing Record 47 of Set 9 | henties bay
# Processing Record 48 of Set 9 | aswan
# Processing Record 49 of Set 9 | taoudenni
# Processing Record 50 of Set 9 | hofn
# Processing Record 1 of Set 10 | nhamunda
# Processing Record 2 of Set 10 | dromolaxia
# Processing Record 3 of Set 10 | jambi
# Processing Record 4 of Set 10 | verkh-usugli
# Processing Record 5 of Set 10 | abashiri
# Processing Record 6 of Set 10 | jati
# Processing Record 7 of Set 10 | jawa
# Processing Record 8 of Set 10 | beatrice
# Processing Record 9 of Set 10 | chibuto
# Processing Record 10 of Set 10 | dubbo
# Processing Record 11 of Set 10 | glushkovo
# Processing Record 12 of Set 10 | olafsvik
# Processing Record 13 of Set 10 | coos bay
# Processing Record 14 of Set 10 | suozhen
# Processing Record 15 of Set 10 | sinnamary
# Processing Record 16 of Set 10 | camopi
# Processing Record 17 of Set 10 | hakvik
# City not found. Skipping...
# Processing Record 18 of Set 10 | lewistown
# Processing Record 19 of Set 10 | krasnoselkup
# Processing Record 20 of Set 10 | beloha
# Processing Record 21 of Set 10 | ahuimanu
# Processing Record 22 of Set 10 | hazorasp
# Processing Record 23 of Set 10 | nizwa
# Processing Record 24 of Set 10 | severnyy
# Processing Record 25 of Set 10 | ballina
# Processing Record 26 of Set 10 | voh
# Processing Record 27 of Set 10 | rozhyshche
# Processing Record 28 of Set 10 | paralimni
# Processing Record 29 of Set 10 | svetlyy
# Processing Record 30 of Set 10 | calmar
# Processing Record 31 of Set 10 | hobyo
# Processing Record 32 of Set 10 | burnie
# Processing Record 33 of Set 10 | hamilton
# Processing Record 34 of Set 10 | naliya
# Processing Record 35 of Set 10 | kenora
# Processing Record 36 of Set 10 | lahaina
# Processing Record 37 of Set 10 | helong
# Processing Record 38 of Set 10 | tres arroyos
# Processing Record 39 of Set 10 | kirakira
# Processing Record 40 of Set 10 | aranos
# Processing Record 41 of Set 10 | teguise
# Processing Record 42 of Set 10 | ferrol
# Processing Record 43 of Set 10 | pangnirtung
# Processing Record 44 of Set 10 | coquimbo
# Processing Record 45 of Set 10 | manta
# Processing Record 46 of Set 10 | kayerkan
# Processing Record 47 of Set 10 | ahipara
# Processing Record 48 of Set 10 | lima
# Processing Record 49 of Set 10 | zabol
# Processing Record 50 of Set 10 | nemuro
# Processing Record 1 of Set 11 | padampur
# Processing Record 2 of Set 11 | solnechnyy
# Processing Record 3 of Set 11 | isa khel
# Processing Record 4 of Set 11 | preobrazheniye
# Processing Record 5 of Set 11 | isiolo
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | yelizovo
# Processing Record 8 of Set 11 | ramgarh
# Processing Record 9 of Set 11 | simao
# Processing Record 10 of Set 11 | menongue
# Processing Record 11 of Set 11 | zhenlai
# Processing Record 12 of Set 11 | lerwick
# Processing Record 13 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 11 | llangefni
# Processing Record 15 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 16 of Set 11 | carutapera
# Processing Record 17 of Set 11 | storslett
# Processing Record 18 of Set 11 | mongo
# Processing Record 19 of Set 11 | miyako
# Processing Record 20 of Set 11 | buraydah
# Processing Record 21 of Set 11 | vanimo
# Processing Record 22 of Set 11 | pisco
# Processing Record 23 of Set 11 | bemidji
# Processing Record 24 of Set 11 | ukiah
# Processing Record 25 of Set 11 | nuuk
# Processing Record 26 of Set 11 | konstantinovka
# Processing Record 27 of Set 11 | sanlucar de barrameda
# Processing Record 28 of Set 11 | bandar
# Processing Record 29 of Set 11 | eyrarbakki
# Processing Record 30 of Set 11 | mount gambier
# Processing Record 31 of Set 11 | kenscoff
# Processing Record 32 of Set 11 | gijon
# Processing Record 33 of Set 11 | parrita
# Processing Record 34 of Set 11 | ilebo
# Processing Record 35 of Set 11 | ghanzi
# Processing Record 36 of Set 11 | baherden
# Processing Record 37 of Set 11 | leiyang
# Processing Record 38 of Set 11 | zarubino
# Processing Record 39 of Set 11 | touros
# Processing Record 40 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 41 of Set 11 | marawi
# Processing Record 42 of Set 11 | coahuayana
# Processing Record 43 of Set 11 | santa lucia
# Processing Record 44 of Set 11 | digby
# Processing Record 45 of Set 11 | myitkyina
# Processing Record 46 of Set 11 | sambek
# Processing Record 47 of Set 11 | fare
# Processing Record 48 of Set 11 | yulara
# Processing Record 49 of Set 11 | odweyne
# Processing Record 50 of Set 11 | lodingen
# Processing Record 1 of Set 12 | atikokan
# Processing Record 2 of Set 12 | tarko-sale
# Processing Record 3 of Set 12 | inhuma
# Processing Record 4 of Set 12 | yelan
# Processing Record 5 of Set 12 | mpika
# Processing Record 6 of Set 12 | manali
# Processing Record 7 of Set 12 | pedernales
# Processing Record 8 of Set 12 | kalawit
# Processing Record 9 of Set 12 | brae
# Processing Record 10 of Set 12 | guanica
# Processing Record 11 of Set 12 | klaksvik
# Processing Record 12 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 12 | bagdarin
# Processing Record 14 of Set 12 | linden
# Processing Record 15 of Set 12 | sao paulo de olivenca
# Processing Record 16 of Set 12 | manavalakurichi
# Processing Record 17 of Set 12 | mongu
# Processing Record 18 of Set 12 | bilma
# Processing Record 19 of Set 12 | the valley
# Processing Record 20 of Set 12 | nisia floresta
# Processing Record 21 of Set 12 | ibra
# Processing Record 22 of Set 12 | tukrah
# Processing Record 23 of Set 12 | kadaya
# Processing Record 24 of Set 12 | mutoko
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | capannori
# Processing Record 27 of Set 12 | gisborne
# Processing Record 28 of Set 12 | jacareacanga
# Processing Record 29 of Set 12 | sao filipe
# Processing Record 30 of Set 12 | khani
# Processing Record 31 of Set 12 | ondjiva
# Processing Record 32 of Set 12 | solikamsk
# Processing Record 33 of Set 12 | la romana
# Processing Record 34 of Set 12 | cartagena
# Processing Record 35 of Set 12 | dzhebariki-khaya
# Processing Record 36 of Set 12 | kinsale
# Processing Record 37 of Set 12 | ban nahin
# Processing Record 38 of Set 12 | zhangye
# Processing Record 39 of Set 12 | altay
# Processing Record 40 of Set 12 | palmeira
# Processing Record 41 of Set 12 | stornoway
# Processing Record 42 of Set 12 | urucara
# Processing Record 43 of Set 12 | shahgarh
# Processing Record 44 of Set 12 | nazilli
# Processing Record 45 of Set 12 | hermiston
# Processing Record 46 of Set 12 | bella union
# Processing Record 47 of Set 12 | niamey
# Processing Record 48 of Set 12 | north bend
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | anzio
# Processing Record 1 of Set 13 | tsaratanana
# Processing Record 2 of Set 13 | dhidhdhoo
# Processing Record 3 of Set 13 | bom jardim
# Processing Record 4 of Set 13 | narsaq
# Processing Record 5 of Set 13 | nadym
# Processing Record 6 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 13 | sanmenxia
# Processing Record 8 of Set 13 | ucluelet
# Processing Record 9 of Set 13 | thinadhoo
# Processing Record 10 of Set 13 | tyukalinsk
# Processing Record 11 of Set 13 | yanam
# Processing Record 12 of Set 13 | waingapu
# Processing Record 13 of Set 13 | mankono
# Processing Record 14 of Set 13 | pemba
# Processing Record 15 of Set 13 | hualmay
# Processing Record 16 of Set 13 | micoud
# Processing Record 17 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 13 | polovinnoye
# Processing Record 19 of Set 13 | bandarbeyla
# Processing Record 20 of Set 13 | zonguldak
# Processing Record 21 of Set 13 | cantanhede
# Processing Record 22 of Set 13 | padang
# Processing Record 23 of Set 13 | ulety
# Processing Record 24 of Set 13 | havre-saint-pierre
# Processing Record 25 of Set 13 | silver city
# Processing Record 26 of Set 13 | jibuti
# Processing Record 27 of Set 13 | labrea
# Processing Record 28 of Set 13 | verkhnevilyuysk
# Processing Record 29 of Set 13 | salinopolis
# Processing Record 30 of Set 13 | nevers
# Processing Record 31 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 13 | stromness
# Processing Record 33 of Set 13 | rock sound
# Processing Record 34 of Set 13 | yantai
# Processing Record 35 of Set 13 | sechura
# Processing Record 36 of Set 13 | vryburg
# Processing Record 37 of Set 13 | moa
# Processing Record 38 of Set 13 | pochutla
# Processing Record 39 of Set 13 | ramanuj ganj
# Processing Record 40 of Set 13 | banki
# Processing Record 41 of Set 13 | kemin
# Processing Record 42 of Set 13 | pitimbu
# Processing Record 43 of Set 13 | zhezkazgan
# Processing Record 44 of Set 13 | manaus
# Processing Record 45 of Set 13 | palasa
# Processing Record 46 of Set 13 | constitucion
# Processing Record 47 of Set 13 | zhigansk
# Processing Record 48 of Set 13 | baghdad
# Processing Record 49 of Set 13 | bridlington
# Processing Record 50 of Set 13 | petalcingo
# Processing Record 1 of Set 14 | malkangiri
# Processing Record 2 of Set 14 | prabumulih
# Processing Record 3 of Set 14 | misratah
# Processing Record 4 of Set 14 | tayu
# Processing Record 5 of Set 14 | saint-pierre
# Processing Record 6 of Set 14 | burhaniye
# Processing Record 7 of Set 14 | miracema do tocantins
# Processing Record 8 of Set 14 | ebbs
# Processing Record 9 of Set 14 | hammerfest
# Processing Record 10 of Set 14 | anito
# Processing Record 11 of Set 14 | lagarto
# Processing Record 12 of Set 14 | ancud
# Processing Record 13 of Set 14 | ixtapa
# Processing Record 14 of Set 14 | santa isabel do rio negro
# Processing Record 15 of Set 14 | sakakah
# Processing Record 16 of Set 14 | japura
# Processing Record 17 of Set 14 | normandin
# Processing Record 18 of Set 14 | larsnes
# Processing Record 19 of Set 14 | mana
# Processing Record 20 of Set 14 | tumpat
# Processing Record 21 of Set 14 | metro
# Processing Record 22 of Set 14 | kaseda
# Processing Record 23 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 24 of Set 14 | vostok
# Processing Record 25 of Set 14 | liuzhou
# Processing Record 26 of Set 14 | daru
# Processing Record 27 of Set 14 | manokwari
# Processing Record 28 of Set 14 | oktyabrskoye
# Processing Record 29 of Set 14 | san jose
# Processing Record 30 of Set 14 | mosquera
# Processing Record 31 of Set 14 | eureka
# Processing Record 32 of Set 14 | meulaboh
# Processing Record 33 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 14 | ozinki
# Processing Record 35 of Set 14 | akot
# Processing Record 36 of Set 14 | mao
# Processing Record 37 of Set 14 | elwood
# Processing Record 38 of Set 14 | naze
# Processing Record 39 of Set 14 | kaili
# Processing Record 40 of Set 14 | srednekolymsk
# Processing Record 41 of Set 14 | kannur
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | morehead
# Processing Record 44 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 14 | pokrovka
# Processing Record 46 of Set 14 | mumbwa
# Processing Record 47 of Set 14 | hailar
# Processing Record 48 of Set 14 | palu
# Processing Record 49 of Set 14 | appleton
# Processing Record 50 of Set 14 | vaasa
# Processing Record 1 of Set 15 | sainte-maxime
# Processing Record 2 of Set 15 | kingisepp
# Processing Record 3 of Set 15 | capreol
# Processing Record 4 of Set 15 | sobolevo
# Processing Record 5 of Set 15 | necochea
# Processing Record 6 of Set 15 | birin
# Processing Record 7 of Set 15 | pacific grove
# Processing Record 8 of Set 15 | sitka
# Processing Record 9 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 15 | ugoofaaru
# Processing Record 11 of Set 15 | majene
# Processing Record 12 of Set 15 | orbetello
# Processing Record 13 of Set 15 | mafeteng
# Processing Record 14 of Set 15 | polyarnyy
# Processing Record 15 of Set 15 | bo rai
# Processing Record 16 of Set 15 | caravelas
# Processing Record 17 of Set 15 | kamenka
# Processing Record 18 of Set 15 | belmonte
# Processing Record 19 of Set 15 | mareeba
# Processing Record 20 of Set 15 | baran
# Processing Record 21 of Set 15 | loviisa
# Processing Record 22 of Set 15 | puerto baquerizo moreno
# Processing Record 23 of Set 15 | palmer
# Processing Record 24 of Set 15 | hukuntsi
# Processing Record 25 of Set 15 | niksic
# Processing Record 26 of Set 15 | panaba
# Processing Record 27 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 15 | mnogovershinnyy
# Processing Record 29 of Set 15 | pangody
# Processing Record 30 of Set 15 | linhai
# Processing Record 31 of Set 15 | amga
# Processing Record 32 of Set 15 | riyadh
# Processing Record 33 of Set 15 | dulce nombre de culmi
# Processing Record 34 of Set 15 | dunedin
# Processing Record 35 of Set 15 | karasburg
# Processing Record 36 of Set 15 | vestmannaeyjar
# Processing Record 37 of Set 15 | nuevo progreso
# Processing Record 38 of Set 15 | mehran
# Processing Record 39 of Set 15 | shache
# Processing Record 40 of Set 15 | clearlake
# Processing Record 41 of Set 15 | acajutiba
# Processing Record 42 of Set 15 | islamkot
# Processing Record 43 of Set 15 | sorong
# Processing Record 44 of Set 15 | moree
# Processing Record 45 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 46 of Set 15 | hami
# Processing Record 47 of Set 15 | sioux lookout
# Processing Record 48 of Set 15 | doka
# Processing Record 49 of Set 15 | shepsi
# Processing Record 50 of Set 15 | quelimane
# Processing Record 1 of Set 16 | kathu
# Processing Record 2 of Set 16 | imbituba
# Processing Record 3 of Set 16 | bandikui
# Processing Record 4 of Set 16 | yichang
# Processing Record 5 of Set 16 | kurilsk
# Processing Record 6 of Set 16 | huilong
# Processing Record 7 of Set 16 | wewak
# Processing Record 8 of Set 16 | takoradi
# Processing Record 9 of Set 16 | goalpara
# Processing Record 10 of Set 16 | holoby
# Processing Record 11 of Set 16 | moron
# Processing Record 12 of Set 16 | puerto carreno
# Processing Record 13 of Set 16 | boma
# Processing Record 14 of Set 16 | puerto escondido
# Processing Record 15 of Set 16 | puerto colombia
# Processing Record 16 of Set 16 | daxian
# City not found. Skipping...
# Processing Record 17 of Set 16 | torres
# Processing Record 18 of Set 16 | moose factory
# Processing Record 19 of Set 16 | mae sai
# Processing Record 20 of Set 16 | katima mulilo
# Processing Record 21 of Set 16 | bell ville
# Processing Record 22 of Set 16 | san quintin
# Processing Record 23 of Set 16 | jilin
# Processing Record 24 of Set 16 | guerrero negro
# Processing Record 25 of Set 16 | san vicente
# Processing Record 26 of Set 16 | sao felix do xingu
# Processing Record 27 of Set 16 | warrington
# Processing Record 28 of Set 16 | alenquer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng Currently  Max Temp  Humidity  \
# 0             Noumea -22.2763  166.4572     Clear     71.01        99
# 1  Sao Joao Da Barra -21.6403  -41.0511     Clear     84.29        75
# 2    Barra Do Garcas -15.8900  -52.2567     Clear     96.17        16
# 3             Barrow  71.2906 -156.7887      Rain     48.22        91
# 4             Manono  -7.3000   27.4167    Clouds     81.07        26
# 5            Xai-Xai -25.0519   33.6442     Clear     62.01        71
# 6          Carnarvon -24.8667  113.6333     Clear     55.47        57
# 7      Mbanza-Ngungu  -5.2500   14.8667    Clouds     80.20        41
# 8            Muborak  39.2553   65.1528    Clouds     88.65        17
# 9              Kapaa  22.0752 -159.3190    Clouds     77.32        83
#
#    Cloudiness  Wind Speed Country                 Date
# 0           0        4.12      NC  2021-07-17 16:30:40
# 1           3       11.99      BR  2021-07-17 16:28:03
# 2           0        2.04      BR  2021-07-17 16:30:40
# 3          90       14.97      US  2021-07-17 16:30:41
# 4          42        7.94      CD  2021-07-17 16:30:41
# 5           0        6.89      MZ  2021-07-17 16:30:41
# 6           5        6.91      AU  2021-07-17 16:30:41
# 7          84        4.25      CD  2021-07-17 16:30:42
# 8          67       16.93      UZ  2021-07-17 16:30:42
# 9          75       13.80      US  2021-07-17 16:30:42

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
